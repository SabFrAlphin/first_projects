# %%
import re 
import requests
from bs4 import BeautifulSoup as soup
import pandas as pd

# %%
#url = input('https://genius.com/Elton-john-your-song-lyrics')
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}
url ='https://www.lyrics.com'
artist_url = 'https://www.lyrics.com/artist.php?name=Elton-John&aid=4617&o=1'

# %%
container = requests.get(artist_url, headers)

# %%
container_html = soup(container.text, 'html.parser')
container_html
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]> <html class="no-js lt-ie9 lt-ie8 lt-ie7" lang="en"> <![endif]-->
# <!--[if IE 7]>    <html class="no-js lt-ie9 lt-ie8" lang="en"> <![endif]-->
# <!--[if IE 8]>    <html class="no-js lt-ie9" lang="en"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en"> <!--<![endif]--><head>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <title>Elton John Lyrics</title>
# <meta content="Elton John Lyrics - All the great songs and their lyrics from Elton John on Lyrics.com" name="description"/>
# <meta content="Elton John lyrics, Elton John song lyrics, Elton John lyric" name="keywords"/>
# <meta content="width=device-width" name="viewport"/>
# <base href="https://www.lyrics.com/"/>
# <script>version='1.1.89';allowed_url=1;</script>
# <!-- Bootstrap compiled and minified CSS -->
# <link href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.2/css/bootstrap.min.css" rel="stylesheet"/>
# ...

# %%
link=container_html.find_all('a', href=True)
link
# Out:
# [<a href="login.php">Login</a>,
#  <a href="https://www.abbreviations.com/">ABBREVIATIONS</a>,
#  <a href="https://www.anagrams.net/">ANAGRAMS</a>,
#  <a href="https://www.biographies.net/">BIOGRAPHIES</a>,
#  <a href="https://www.convert.net/">CONVERSIONS</a>,
#  <a href="https://www.definitions.net/">DEFINITIONS</a>,
#  <a href="https://www.grammar.com/">GRAMMAR</a>,
#  <a href="https://www.literature.com/">LITERATURE</a>,
#  <a href="https://www.lyrics.com/">LYRICS</a>,
#  <a href="http://math.stands4.com/">MATH</a>,
#  <a href="https://www.phrases.com/">PHRASES</a>,
#  <a href="https://www.poetry.net/">POETRY</a>,
#  <a href="https://www.quotes.net/">QUOTES</a>,
#  <a href="https://www.references.net/">REFERENCES</a>,
#  <a href="https://www.rhymes.net/">RHYMES</a>,
#  <a href="https://www.scripts.com/">SCRIPTS</a>,
#  <a href="https://www.symbols.com/">SYMBOLS</a>,
#  <a href="https://www.synonyms.com/">SYNONYMS</a>,
#  <a href="https://www.uszip.com/">USZIP</a>,
# ...

# %%
all_links = [x.get('href') for x in link if r'/lyric' in x.get('href')]
all_links
# Out:
# ['/lyric/8342215/Elton+John/%28Gotta+Get+A%29+Meal+Ticket',
#  '/lyric/10483376/Elton+John/%28Gotta+Get+A%29+Meal+Ticket',
#  '/lyric/27157458/Elton+John/%28Gotta+Get+A%29+Meal+Ticket',
#  '/lyric/35172462/Elton+John/%28Gotta+Get+A%29+Meal+Ticket',
#  '/lyric/1067478/Elton+John/%28Ho%21+Ho%21+Ho%21%29+Who%27d+Be+a+Turkey+at+Christmas',
#  '/lyric/1421719/Elton+John/%28Ho%21+Ho%21+Ho%21%29+Who%27d+Be+a+Turkey+at+Christmas',
#  '/lyric/36811957/Elton+John/%28I%27m+Gonna%29+Love+Me+Again',
#  '/lyric/36239961/Elton+John/%28I%27m+Gonna%29+Love+Me+Again',
#  '/lyric/36223600/Elton+John/%28I%27m+Gonna%29+Love+Me+Again',
#  '/lyric/36222647/Elton+John/%28I%27m+Gonna%29+Love+Me+Again',
#  '/lyric/36220870/Elton+John/%28I%27m+Gonna%29+Love+Me+Again',
#  '/lyric/32667836/Elton+John/16th+Century+Man',
#  '/lyric/3423856/Elton+John/16th+Century+Man',
#  '/lyric/3574226/Elton+John/16th+Century+Man',
#  '/lyric/10239599/Elton+John/2+Man+Show',
#  '/lyric/12182861/Elton+John/2+Man+Show',
# ...

# %%
df = pd.DataFrame(columns=['title','text'])
df
# Out:
# Empty DataFrame
# Columns: [title, text]
# Index: []

# %%
for a in all_links[:100]:
    response = requests.get(url+a)
    response_html = soup(response.text, 'html.parser')
    response_text=response_html.find_all('pre',attrs={"id":"lyric-body-text"})
    response_title = response_html.find('h1',attrs={"class":"lyric-title"}).text
    for i in response_text:
        song = i.text
        df = df.append([song],ignore_index=True)
df.to_csv('elton.csv')

# %%
song_book.to_csv('elton.csv')

# %% [markdown]
# ### test version

# %%
df2 = pd.DataFrame(columns=['title','text'])
#(columns=['title','text'])
df2
# Out:
# Empty DataFrame
# Columns: [title, text]
# Index: []

# %%
response1 = requests.get(url+'/lyric/29276852/Elton+John/Rocket+Man')
response_html1 = soup(response1.text, 'html.parser')
response_text1 = response_html1.find_all('pre',attrs={"id":"lyric-body-text"})
response_title1 = response_html1.find('h1',attrs={"class":"lyric-title"}).text
for i in response_text1:
    song1 = i.text
    df3 = df2.append({'text':song1},{'title':response_title1},sort=True)
df3
# Out:
#                                                 text title
# 0  She packed my bags last night pre-flight\nZero...   NaN

# %% [markdown]
# ## other versions

# %%
response1 = requests.get(url+'/lyric/29276852/Elton+John/Rocket+Man')
response_html1 = soup(response1.text, 'html.parser')
response_text1 = response_html1.find_all('pre',attrs={"id":"lyric-body-text"})
response_title1 = response_html1.find('h1',attrs={"class":"lyric-title"}).text
df3 = pd.Data
for i in response_text1:
    song1 = i.text
    df3 = df2.append({'text':song1},{'title':response_title1},sort=True)
df3

# %%
response1 = requests.get(url+'/lyric/29276852/Elton+John/Rocket+Man')
response_html1 = soup(response1.text, 'html.parser')
response_text1 = response_html1.find_all('pre',attrs={"id":"lyric-body-text"})
response_title1 = response_html1.find('h1',attrs={"class":"lyric-title"}).text
#df3 = df2.append({'title': response_title1}, ignore_index=True)
for i in response_text1:
    song1 = i.text
   # df4 = df3.append({'text':song1}, ignore_index=True)
df4

                 # ['text']
# df2 = df2.append([song1], columns=['text'],ignore_index=True)
# df2 = df2.append(({'text':song1}, ignore_index=True),({'title':response_title1}, ignore_index=True)

# %%
response1 = requests.get(url+'/lyric/29276852/Elton+John/Rocket+Man')
response_html1 = soup(response1.text, 'html.parser')
response_title1 = response_html1.find('h1',attrs={"class":"lyric-title"}).text
#response_title1 = pd.Series(response_title1)
df2 = df2.append({'title':response_title1}, ignore_index=True)
df2

# %%
links = container_html.find_all('a', href=True)
for a in links:
    link = re.findall(r"href=\"/(lyric/\w+)",container_html.find_all('a', href=True))
    print(link)
#    with open('elton.txt', 'w') as f:
#        f.write('link')

# %%
#elton = container_html.find_all('a', href=True)
#href=\"/(lyric/\w+)
links = re.findall('href=\"', link, flags=0)
links

# %%
#save links to file
with open('elton.txt', 'w') as f:
    for item in link:
        f.write("%s\n" % item)

# %%
#links = [a['href'] for a in container_html.find_all('a', href=True)]

# %%
for a in container_html.find_all('a', href=True):
    link = a['href']
    print(link)
#    with open('elton.txt', 'w') as f:
#        f.write('link')
